# %%
import requests
import pyautogui as pag
import selenium
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import Chrome
from selenium.webdriver import ChromeOptions
options = ChromeOptions()
options.headless = False #headless browser
driver = Chrome(executable_path='/home/sol/notebooks/web_scraper_python/chromedriver', options = options)

#login twitter
username = '@yourusername'
password = 'dfyuiydfusydfu'

driver.get('https://twitter.com/REMAXAdamContos/followers') #start url
driver.maximize_window()
time.sleep(2)
driver.find_element_by_xpath('//*[@id="react-root"]/div/div/div[2]/main/div/div/div/div/div/div[2]/div/div/div[1]/div/div[5]/div[2]/a').click()
time.sleep(2)
driver.find_element_by_xpath('//*[@id="layers"]/div[2]/div/div/div/div/div/div[2]/div[2]/div/div[2]/div/div[2]/div[2]/a[1]/div/span/span').click()
time.sleep(4)
driver.find_element_by_xpath('//*[@id="layers"]/div[2]/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div[5]/label/div/div[2]/div/input').send_keys(username)
driver.find_element_by_xpath('//*[@id="layers"]/div[2]/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div[6]/div/span/span').click()
time.sleep(4)
driver.find_element_by_xpath('//*[@id="layers"]/div[2]/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[1]/div/div[3]/div/label/div/div[2]/div[1]/input').send_keys(password)
driver.find_element_by_xpath('//*[@id="layers"]/div[2]/div/div/div/div/div/div[2]/div[2]/div/div/div[2]/div[2]/div[2]/div/div/div/span/span').click()
time.sleep(4)
driver.get('https://twitter.com/REMAXAdamContos/followers') #start url

# %%
#use a gui function to scroll the page
raw_data =[]
for i in range(20):
    for span in driver.find_elements_by_tag_name('span'):
        raw_data.append(span.text)
    pag.dragTo(2552, 1008, 2, button='left')
    time.sleep(2)

# %%
#all the span elements
raw_data
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  'Home',
#  'Explore',
#  'Notifications',
#  'Messages',
#  'Bookmarks',
#  'Lists',
#  'Profile',
#  'More',
#  'Tweet',
#  'Tweet',
#  'Tweet',
#  'General Scraper',
#  'General Scraper',
#  '@GeneralScraper',
#  '',
#  '@REMAXAdamContos',
#  '',
#  'Followers',
#  'Following',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Home',
#  'Explore',
#  '6',
#  'Notifications',
#  'Messages',
#  'Bookmarks',
#  'Lists',
#  'Profile',
#  'More',
#  'Tweet',
#  'Tweet',
#  'Tweet',
#  'General Scraper',
#  'General Scraper',
#  '@GeneralScraper',
#  '',
#  'Adam Contos',
#  '@REMAXAdamContos',
#  '',
#  'Followers',
#  'Following',
#  '',
#  '',
#  'RE/MAX',
#  'RE/MAX',
#  '@remax',
#  'Follow',
#  'Follow',
#  'Every day we do more to help buyers and sellers realize their dreams. Come on in and stay awhile!',
#  '#REMAXHustle',
#  'Tom Ferry',
#  'Tom Ferry',
#  '@tomferry',
#  'Follow',
#  'Follow',
#  '#TomFerry',
#  'No.1',
#  '#RealEstateCoaching',
# ...

# %%
#filter with regex
import re
pattern = re.compile(r'^@.+') 
folowers = [x for x in raw_data if re.search(r'^@.+', x)]
folowers
# Out:
# ['@GeneralScraper',
#  '@REMAXAdamContos',
#  '@GeneralScraper',
#  '@REMAXAdamContos',
#  '@remax',
#  '@tomferry',
#  '@jimmymackin',
#  '@Chris_Smth',
#  '@samdebord',
#  '@RESOstandards',
#  '@NARreach',
#  '@inmannews',
#  '@realtormag',
#  '@katielance',
#  '@NateSmoyer',
#  '@TechNestPodcast',
#  '@HelloAvail',
#  '@realtordotcom',
#  '@REMAXca',
#  '@JordanCohen21',
#  '@realtorpro',
#  '@CMNHospitals',
#  '@arielchampanier',
#  '@MottoMortgage',
#  '@LinsellChris',
#  '@JediRealEstate',
#  '@MoxiWorks',
#  '@GordonTredgold',
#  '@EricStegemann',
#  '@TRIBUS',
#  '@ReMaxAllStar',
#  '@retechruss',
#  '@EarnnestApp',
#  '@HouseCanary',
#  '@realscout',
#  '@trulia',
#  '@NARREACH',
#  '@uoregon',
#  '@RISMediaUpdates',
#  '@HousecallBlog',
#  '@CrystalCappsBH',
#  '@Elistudentloan',
#  '@robindschneider',
#  '@homewchristin',
#  '@LynxKite',
#  '@rstudiotips',
#  '@Rbloggers',
#  '@GeneralScraper',
#  '@REMAXAdamContos',
#  '@remax',
#  '@tomferry',
#  '@jimmymackin',
# ...

# %%
len(folowers)
# Out:
# 1024
